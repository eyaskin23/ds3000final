# %%
# test
import pandas as pd
df = pd.read_csv('VSRR_Provisional_Drug_Overdose_Death_Counts.csv')

df = df.dropna(subset=['Percent Complete'])
df = df.dropna(subset=['Predicted Value'])
df = df.dropna(subset=['Data Value'])


df.head(10)
# Out:
#     State  Year     Month           Period  \
# 11     AK  2015     April  12 month-ending
# 19     AK  2015    August  12 month-ending
# 25     AK  2015  December  12 month-ending
# 41     AK  2015  February  12 month-ending
# 54     AK  2015   January  12 month-ending
# 66     AK  2015      July  12 month-ending
# 76     AK  2015      June  12 month-ending
# 92     AK  2015     March  12 month-ending
# 99     AK  2015       May  12 month-ending
# 108    AK  2015  November  12 month-ending
#
#                                       Indicator Data Value  Percent Complete  \
# 11               Number of Drug Overdose Deaths        126             100.0
# 19               Number of Drug Overdose Deaths        124             100.0
# 25               Number of Drug Overdose Deaths        121             100.0
# 41               Number of Drug Overdose Deaths        127             100.0
# 54               Number of Drug Overdose Deaths        126             100.0
# 66               Number of Drug Overdose Deaths        117             100.0
# 76               Number of Drug Overdose Deaths        121             100.0
# 92               Number of Drug Overdose Deaths        125             100.0
# 99               Number of Drug Overdose Deaths        125             100.0
# 108  Synthetic opioids, excl. methadone (T40.4)         15             100.0
#
#      Percent Pending Investigation State Name  \
# 11                             0.0     Alaska
# 19                             0.0     Alaska
# 25                             0.0     Alaska
# 41                             0.0     Alaska
# 54                             0.0     Alaska
# 66                             0.0     Alaska
# 76                             0.0     Alaska
# 92                             0.0     Alaska
# 99                             0.0     Alaska
# 108                            0.0     Alaska
#
#                                               Footnote Footnote Symbol  \
# 11   Numbers may differ from published reports usin...              **
# 19   Numbers may differ from published reports usin...              **
# 25   Numbers may differ from published reports usin...              **
# 41   Numbers may differ from published reports usin...              **
# 54   Numbers may differ from published reports usin...              **
# 66   Numbers may differ from published reports usin...              **
# 76   Numbers may differ from published reports usin...              **
# 92   Numbers may differ from published reports usin...              **
# 99   Numbers may differ from published reports usin...              **
# 108  Numbers may differ from published reports usin...              **
#
#     Predicted Value
# 11              126
# 19              124
# 25              121
# 41              127
# 54              126
# 66              117
# 76              121
# 92              125
# 99              125
# 108              15

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df['State'] = df['State'].astype("string")
df['Period'] = df['Period'].astype("string")
df['Indicator'] = df['Indicator'].astype("string")

df['Data Value'] = pd.to_numeric(df['Data Value'], errors='coerce')

df['Data Value'] = df['Data Value'].fillna(0).astype("int64")

df['Month'] = df['Month'].astype("string")
df['Footnote'] = df['Footnote'].astype("string")
df['Footnote Symbol'] = df['Footnote Symbol'].astype("string")
df['State Name'] = df['State Name'].astype("string")
df['Predicted Value'] = df['Predicted Value'].astype("string")

df = df.dropna(subset=['Percent Complete'])
df = df.dropna(subset=['Percent Pending Investigation'])

df.describe()
# Out:
#                Year    Data Value  Percent Complete  \
# count  37949.000000  37949.000000      37949.000000
# mean    2019.084218    211.640491         99.999881
# std        2.323629    241.300405          0.007699
# min     2015.000000      0.000000         99.500000
# 25%     2017.000000     17.000000        100.000000
# 50%     2019.000000    114.000000        100.000000
# 75%     2021.000000    339.000000        100.000000
# max     2023.000000    999.000000        100.000000
#
#        Percent Pending Investigation
# count                   37949.000000
# mean                        0.118360
# std                         0.154831
# min                         0.000000
# 25%                         0.017560
# 50%                         0.057023
# 75%                         0.152901
# max                         1.632556

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = df.dropna(subset=['Predicted Value'])
df = df.dropna(subset=['Data Value'])

death_counts_per_year = df.groupby(['Year', 'Data Value']).size().reset_index(name='Frequency')

total_death_counts_per_year = death_counts_per_year.groupby('Year')['Frequency'].sum().reset_index(name='Total Deaths')

plt.figure(figsize=(8, 6))
sns.lineplot(x='Year', y='Total Deaths', data=total_death_counts_per_year, marker='o')
plt.title('Total Death Counts Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Deaths')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = df.dropna(subset=['Predicted Value'])
df = df.dropna(subset=['Data Value'])

death_counts_per_month = df.groupby(['Month']).size().reset_index(name='Total Deaths')

plt.figure(figsize=(6, 4))
plt.pie(death_counts_per_month['Total Deaths'], labels=death_counts_per_month['Month'], autopct='%1.1f%%', startangle=140)
plt.title('Total Death Counts Across Months')
plt.axis('equal') 

plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Indicator', y='Data Value', data=df)
plt.title('Number of Deaths by Indicator')
plt.xlabel('Indicator')
plt.ylabel('Number of Deaths')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is loaded into a DataFrame called 'df'
# If not, you can load it using: df = pd.read_csv('your_dataset.csv')

df = df.dropna(subset=['Predicted Value'])
df = df.dropna(subset=['Data Value'])

# Bar graph for deaths per state
plt.figure(figsize=(14, 8))
sns.barplot(x='State', y='Data Value', data=df)
plt.title('Number of Deaths per State')
plt.xlabel('State')
plt.ylabel('Number of Deaths')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
